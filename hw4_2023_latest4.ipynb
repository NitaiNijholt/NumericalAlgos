# %% [markdown]
# # Homework set 4

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected (in the menubar, select Kernel → Restart Kernel and Run All Cells...).
#
# Please **submit this Jupyter notebook through Canvas** no later than **Mon Nov. 27, 9:00**. **Submit the notebook file with your answers (as .ipynb file) and a pdf printout. The pdf version can be used by the teachers to provide feedback. A pdf version can be made using the save and export option in the Jupyter Lab file menu.**
#
# Homework is in **groups of two**, and you are expected to hand in original work. Work that is copied from another group will not be accepted.

# %% [markdown]
# # Exercise 0
# Write down the names + student ID of the people in your group.

# %% [markdown]
# Pablo Rodriguez Alves - 15310191
# Nitai Nijholt - 12709018

# %% [markdown]
# # About imports
# Please import the needed packages by yourself.

# %% [markdown]
# # Sparse matrices
# A _sparse matrix_ or _sparse array_ is a matrix in which most of the elements are zero. There is no strict definition how many elements need to be zero for a matrix to be considered sparse. In many examples, the number of nonzeros per row or column is a small fraction, a few percent or less, of the total number of elements of the row or column. By contrast, if most of the elements are nonzero, then the matrix is considered _dense_.
#
# In the context of software for scientific computing, a sparse matrix typically refers to a storage format, in which elements which are known to be zero are not stored. In Python, the library `scipy.sparse` defines several sparse matrix classes, such as `scipy.sparse.csr_array`. To construct such an object, one passes for each nonzero element the value, and the row and column coordinates. In some cases, one can also just pass the nonzero (off-)diagonals, see `scipy.sparse.diags`.
#
# Functions for dense matrices do not always work with sparse matrices. For example for the product of a sparse matrix with a (dense) vector, there is the member function `scipy.sparse.csr_array.dot`, and for solving linear equations involving a sparse matrix, there is the function `scipy.sparse.linalg.spsolve`.

# %%
# Import some basic packages
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
from scipy.sparse import csr_array

# This is how to create a sparse matrix from a given list of (row, column, value) tuples.
row  = [0,   3,   1,   0]
col  = [0,   3,   1,   2]
data = [4.0, 5.0, 7.0, 9.0]
M = csr_array((data, (row, col)), shape=(4, 4))

print("When printing a sparse matrix, it shows its nonzero entries:")
print(M)

print("If you want to see its `dense` matrix form, you have to use `mat.toarray()`:")
print(M.toarray())

# This is how to perform matrix-vector products.
x = np.array([1, 2, 3, 4])
print("For x={}, Mx = {}".format(x, M.dot(x)))
# Out:
# When printing a sparse matrix, it shows its nonzero entries:
#   (0, 0)	4.0
#   (0, 2)	9.0
#   (1, 1)	7.0
#   (3, 3)	5.0
# If you want to see its `dense` matrix form, you have to use `mat.toarray()`:
# [[4. 0. 9. 0.]
#  [0. 7. 0. 0.]
#  [0. 0. 0. 0.]
#  [0. 0. 0. 5.]]
# For x=[1 2 3 4], Mx = [31. 14.  0. 20.]

# %%
from scipy.sparse import diags, SparseEfficiencyWarning
from scipy.sparse.linalg import spsolve
import warnings
warnings.simplefilter('ignore', SparseEfficiencyWarning)  # Suppress confusing warning

# This is how to create a sparse matrix from a given list of subdiagonals.
diagonals = [[1, 2, 3, 4], [1, 2, 3], [1, 2]]
M = diags(diagonals, [0, 1, 2])
print("This matrix has values on its diagonal and on offdiagonals 1 and 2 rows ABOVE it.")
print(M.toarray())

M = diags(diagonals, [0, -1, -2])
print("This matrix has values on its diagonal and on offdiagonals 1 and 2 rows BELOW it.")
print(M.toarray())

print("If you want to visualize the matrix for yourself, use `plt.imshow`:")
plt.imshow(M.toarray())
plt.colorbar()
plt.show()

# This is how to solve sparse systems.
b = np.array([1, 2, 3, 4])
x = spsolve(M, b)
print("For b={}, the solution x to Mx=b is {}".format(b, x))
print("And indeed, Mx - b = {}".format(M.dot(x) - b))
# Out:
# This matrix has values on its diagonal and on offdiagonals 1 and 2 rows ABOVE it.
# [[1. 1. 1. 0.]
#  [0. 2. 2. 2.]
#  [0. 0. 3. 3.]
#  [0. 0. 0. 4.]]
# This matrix has values on its diagonal and on offdiagonals 1 and 2 rows BELOW it.
# [[1. 0. 0. 0.]
#  [1. 2. 0. 0.]
#  [1. 2. 3. 0.]
#  [0. 2. 3. 4.]]
# If you want to visualize the matrix for yourself, use `plt.imshow`:
# For b=[1 2 3 4], the solution x to Mx=b is [1.         0.5        0.33333333 0.5       ]
# And indeed, Mx - b = [0. 0. 0. 0.]

# %% [markdown]
# --------
# # Exercise 1
# Consider the following boundary value problem involving a nonlinear ordinary differential equation:
#
# $$ \tag{1} y''(x) + \exp(y(x)) = 0, \quad 0 < x < 1, \quad y(0) = y(1) = 0.$$
#
# The purpose of this exercise is to approximate the solution to this boundary value problem, by discretizing the problem and then solving the resulting system of nonlinear equations.

# %% [markdown]
# Problem (1) will be discretized using finite differences. Suppose we use $n+2$ discretization points for $x$, denoted $x_k = kh$ for $k \in \{0, \ldots, n+1\}$ and $h = 1/(n+1)$. The approximate solution is denoted $y_k = y(x_k)$.
#
# We will use a _second-order central finite difference_ approximation for the second derivative:
#
# $$ \tag{2} y''(x_k) \approx \frac{y_{k-1} - 2 y_k + y_{k+1}}{h^2}.$$
#
# The term $\exp(y(x_k))$ can simply be approximated by $\exp(y_k)$. Thus for $x=x_k$, equation (1) becomes
#
# $$ \tag{3} \frac{y_{k-1} - 2 y_k + y_{k+1}}{h^2} + \exp y_k = 0, \quad k = 1, \ldots, n.$$
#
# The boundary conditions (the conditions $y(0) = y(1) = 1$), lead to the requirement that $y_0 = y_{n+1} = 0$. To find the remaining values $y_k$, $k=1, \ldots, n$, equation (3) will be used for $k = 1, \ldots, n$. In this way, one obtains $n$ equations for $n$ unknowns, to which, in principle, a rootfinding method can be applied.
#
# We will write $\vec y = \begin{bmatrix} y_1 \\ \vdots \\ y_n \end{bmatrix}$ for the vector of values to be determined.

# %% [markdown]
# ## (a)  (2 pts)
# As a first step, finish the function `SecondDerMatrix` that returns a matrix $\bf{M}$ that maps the vector $\vec y$ to the vector of the approximate values $y''(x_k)$, $k=1, \ldots, n$ given in (2). To get full points for this part of the exercise you must create output in the form of a sparse matrix.

# %%
from scipy.sparse import csr_array

def SecondDerMatrix(n):
    """ Creates n x n Matrix M such that M * y = y'' """

    # Compute constant h of all elements
    h = 1 / (n + 1)

    #x_k = xk(10)

    # Define the diagonal elements ignoring the h^2 constant:
    # -2 to the main diagonal and 1 for the diagonals around it
    # Also, divide all elements by constant h^2
    main_diagonal  =  -2*np.ones(n) / (h*h)
    top_diagonal   =  np.ones(n-1)  / (h*h)
    under_diagonal =  np.ones(n-1)  / (h*h)

    # Create the sparse matrix with the diagonals defined
    diagonals = [main_diagonal, top_diagonal, under_diagonal]
    M = diags(diagonals, [0, 1, -1]) 
    
    return M

# %%
SecondDerMatrix(10).toarray()
# Out:
# array([[-242.,  121.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#            0.],
#        [ 121., -242.,  121.,    0.,    0.,    0.,    0.,    0.,    0.,
#            0.],
#        [   0.,  121., -242.,  121.,    0.,    0.,    0.,    0.,    0.,
#            0.],
#        [   0.,    0.,  121., -242.,  121.,    0.,    0.,    0.,    0.,
#            0.],
#        [   0.,    0.,    0.,  121., -242.,  121.,    0.,    0.,    0.,
#            0.],
#        [   0.,    0.,    0.,    0.,  121., -242.,  121.,    0.,    0.,
#            0.],
#        [   0.,    0.,    0.,    0.,    0.,  121., -242.,  121.,    0.,
#            0.],
#        [   0.,    0.,    0.,    0.,    0.,    0.,  121., -242.,  121.,
#            0.],
#        [   0.,    0.,    0.,    0.,    0.,    0.,    0.,  121., -242.,
#          121.],
#        [   0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,  121.,
#         -242.]])

# %% [markdown]
# ## (b)  (1 pt)
# Second-order central finite differences are exact for quadratic functions. In order to test your implementation, choose $n=10$ and apply the second derivative matrix from part (a) to a quadratic function $y(x)$ witçh $y(0) = y(1) = 0$ for which you know the second derivative $y''(x)$.

# %%
# Define quadratic function that satisfies y(0)=y(1)=0 
# And a function for its second derivative
def f(x):
    """ Quadratic equation   y = x^2 - x """
    return x**2 - x

def f_second_derivative(x):
    """ Second derivative of y = x^2 - x """
    return 2*np.ones(x.size)

def f_heath(x):
    """ Implements second order central finite difference
    See Heath p.365"""
    h = 1 / (x.size + 1)
    return ( f(x+h) - 2*f(x) + f(x-h) ) / h**2

def xk(n):
    """ Returns vector xk, that has n values"""
    h = 1 / (n + 1)
    xs = h * np.linspace(0,n+1,n+2)[1:-1]
    return xs

# Define constant and input values
n = 10
x = xk(n)

y = f(x)


def f_heath_2(x):
    h = 1 / (x.size + 1)
    v1 = f(x-h)
    v2 = f(x)
    v3 = f(x+h)
    return (v1 - 2*v2 + v3 ) / h**2


# Create second derivative Matrix and
# turn it into array for multiplication
M = SecondDerMatrix(n)
M = M.toarray()

# Multiply y and M to get y'' aproximation
y_second_deriv_approx = M @ y 

# Compute analytical second derivative y''
y_second_deriv = f_second_derivative(x)

# Compute exact approximation as well
y_heath = f_heath(x)

# Compare y'' with its true analytical approximation
error = y_second_deriv - y_second_deriv_approx

print('x',x)
print('y',y)
print("y''",y_second_deriv)
print('y_heath',y_heath)
print("M @ y",y_second_deriv_approx)
print('error',error)
# Out:
# x [0.09090909 0.18181818 0.27272727 0.36363636 0.45454545 0.54545455
#  0.63636364 0.72727273 0.81818182 0.90909091]
# y [-0.08264463 -0.14876033 -0.19834711 -0.23140496 -0.24793388 -0.24793388
#  -0.23140496 -0.19834711 -0.14876033 -0.08264463]
# y'' [2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
# y_heath [2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
# M @ y [2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
# error [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -7.10542736e-15
#   7.10542736e-15  7.10542736e-15]

# %% [markdown]
# ## (c) (2 pts)
#
# Defining $\vec y = \begin{bmatrix} y_1 \\ \vdots \\ y_n \end{bmatrix}$ and
# $E(\vec y) = \begin{bmatrix} \exp(y_1) \\ \vdots \\ \exp(y_n) \end{bmatrix}$, the equations (3) can be written in the form
#
# $$ F(\vec y) := {\bf M} \cdot \vec y + E(\vec y) = \vec 0. $$
#
# Finish the function `F` that defines $F(\vec y) = {\bf M} \cdot \vec y + E(\vec y)$.
# Finish the function `JacobianF` that computes the Jacobian ${\bf J}_F(\vec y)$ of $F(\vec y)$.
# To get full points for this part of the exercise, the Jacobian must be computed in the form of a sparse matrix.

# %%
def F(y):
    """ Creates n x 1 matrix F such that F = M*y + E(y) """
    n = y.size
    M = SecondDerMatrix(n)
    E = np.exp(y)
    F = M @ y + E
    return F
    
def JacobianF(y):
    """ Creates n x n Jacobian matrix of our system 
    which is just M with main diagonal multiplyed by corresponding e^y """

    # Compute constant h
    n = y.size
    h = 1 / (n + 1)

    # Define the diagonal elements ignoring the h^2 constant:
    # -2 + e^y_i to the main diagonal and 1 for the diagonals around it
    main_diagonal = -2*np.ones(n) / h**2 + np.exp(y)
    top_diagonal = np.ones(n-1) / h**2
    under_diagonal = np.ones(n-1) / h**2
    
    # Create the sparse matrix with the diagonals defined
    diagonals = [main_diagonal, top_diagonal, under_diagonal]
    J = diags(diagonals, [0, 1, -1]) 

    
    return J

# %% [markdown]
# ## (d)  (3 pts)
# 1. Write down the first order Taylor expansion $T_F(\vec y, \vec s)$ for $F(\vec y+\vec s)$.
# 2. In order to check your implementation of the Jacobian matrix, compute and print both $F(\vec y+\vec s)$ and its first order Taylor approximation $T_F(\vec y, \vec s)$ for a choice $\vec y$ and $\vec s$.
# 3. Verify numerically that the error $||F(\vec y + \vec s) - T_F(\vec y, \vec s)||_2$ is $\mathcal O(||\vec s||_2^2)$. Hint: take vectors $\vec s$ with $\|\vec s\|_2 = \mathcal O(h)$  for multiple values for $h$, e.g. $h = 10^{-k}$ for a range of $k$.

# %% [markdown]
# #### Subquestion d.1
# Recall that the Taylor expansion of a function around a certain point is given by
#
# $T_f(x,a) = \sum_{n=0}^{\infty} \frac{f^{(n)}(a)}{n!}(x-a)^n$
#
# Where $f$ is our function, $a$ the point of interest, $n!$ the factorial of $n$ and $f^{(n)}(a)$ the nth derivative of f evaluated at that point.
#
# Its first order taylor expansion is given by:
#
# $T_{f,1}(a) = f(a) + f'(a)(x-a)$
#
# In our case
#
# $f(a) = F(\vec y) = {\bf M} \cdot (\vec y ) + E(\vec y)$.
#
# $f'(a) = F'(\vec y) = {\bf M} + E(\vec y)$
#
# $(x-a) = (\vec y - \vec s)$
#
#
# Therefore
#
# $T_{F,1}(\vec{y},\vec{s}) = F(\vec{s}) + J(\vec{s})(\vec y - \vec s)$
#
# <!-- Which can be simplified to
#
# $T_{F,1} = E(\vec s)(\vec 1 + \vec y - \vec s) + M \cdot \vec y$ -->
#
#
# $\blacksquare$

# %%
# Subquestions 2 and 3.

## COMPUTE F(y+s) and TF(y+s) for certain y and s
def T(y,s):
    """Returns the first order Taylor series of function F"""
    return F(s) + JacobianF(s) @ (y-s)

# Get some values
n = 3

y = np.linspace(0,0.5,n)
s = np.linspace(0.2,0.4,n)

F_ys = F(y+s)
T_ys = T(y,s)

print('y', y)
print('s', s)
print('F_ys', F_ys)
print('T_ys', T_ys)
print('')
print("Jacobian: ", JacobianF(y).toarray())


# Subquestion 3
# Verify for many k -> h = 10^-k and s / norm(s)= h
# that 
n = 5
k_values = 10
y = np.linspace(0,0.5,n)

error_list = []
h_list = []
s_list = []

for k in range(k_values):
    h = 10 ** -k

    # append h values to h list
    h_list.append(h)

    s = np.linspace(0,1,n)
    # Scale so s has norm O(h)
    # I ASSUME that O(h) is same as just h
    s = s * (h / np.linalg.norm(s))
    s_list.append(np.linalg.norm(s)**2)


    
    
    # Compute 
    F_ys = F(y+s)
    T_ys = T(y,s)

    # Error
    error = np.linalg.norm(F_ys - T_ys)
    error_list.append(error)

# plotting
plt.scatter(h_list,error_list, label=r'$||F(\vec y + \vec s) - T_F(\vec y, \vec s)||_2$')
plt.scatter(h_list,s_list, label=r'$||(\vec s)||_2^{2}$')
plt.xscale('log')
plt.title(r'First order Taylor aproximation error vs. squared magnituge of pertubation vector $\vec s$')
plt.ylabel(r'$||F(\vec y + \vec s) - T_F(\vec y, \vec s)||_2$')
plt.xlabel('stepsize (h)')
plt.legend()


error_magnitude_difference = [ error_list[index+1]/error_list[index] for index in range(len(error_list)-1)]
s_magnitude_difference = [ s_list[index+1]/s_list[index] for index in range(len(s_list)-1)]

print('\n')
print('error_magnitude_difference',error_magnitude_difference)
print('s_magnitude_difference',s_magnitude_difference)
# Out:
# y [0.   0.25 0.5 ]
# s [0.2 0.3 0.4]
# F_ys [  3.62140276   1.73325302 -17.54039689]
# T_ys [  4.97712221   1.28236587 -10.35899283]
#
# Jacobian:  [[-31.          16.           0.        ]
#  [ 16.         -30.71597458  16.        ]
#  [  0.          16.         -30.35127873]]
#
#
# error_magnitude_difference [0.09832783437083963, 0.06613686191846027, 0.7086033880963042, 1.1600895052346112, 1.0143976503019985, 1.001424314710881, 1.0001422778844524, 1.0000142262535576, 1.0000014226100056]
# s_magnitude_difference [0.010000000000000004, 0.009999999999999998, 0.009999999999999998, 0.01, 0.010000000000000002, 0.009999999999999998, 0.009999999999999998, 0.010000000000000002, 0.01]

# %% [markdown]
# We can see that the magnituge of the error is in the same order of the magnitude of the squared magnitude of perturbation vector s squared, so the relationship $||F(\vec y + \vec s) - T_F(\vec y, \vec s)||_2$ is $\mathcal O(||\vec s||_2^2)$, hold. The relationship breaks down for the last two values of h (where h is close to 1) for which this difference grows exponentially.This corroborates small values of of h for this aproximation to be on the same order of magnitude.

# %% [markdown]
# ## (e) (2 pts)
# 1. Finish the function `NewtonSolve` below to solve the system of equations.
# 2. Take $n=40$, and experiment with your function. Try to find a choice of `y0` such that the method doesn't converge, as well as a choice of `y0` such that the method converges. In your answer, list the types of convergence behavior you found. Show a convergent example (if you found any) and a nonconvergent example (if you found any). Show the solutions you found for each example.

# %%
# Subquestion 1.
def NewtonSolve(y0, K):
    """ Use Newton's method to solve F(y) = 0 with initial guess y0 and K iterations. Returns solution 'y', list of values per iterations 'values' and list of errors per iteration 'errors'
    Algorithm 5.6 in Heath p. 238"""
    # We assume true solution is M @ y + np.exp(y)
    
    values = []
    errors = []
    M = SecondDerMatrix(y0.size)

    # Initial guess
    y = y0
    
    for k in range(K):
        # Solve Jf(xk)sk = -f(xk) for sk
        sk = np.linalg.solve(JacobianF(y).toarray(), -F(y))
        y = y + sk
        
        # saving values for each iteration
        values.append(y)
        
        # Error metric, see heath p.221
        error = y - (M @ y + np.exp(y))

        errors.append(error)

    return y,values,errors

# %%
# y0 values to test, try 3 different cases
y0_test_1 = np.ones(n)
y0_test_2 = np.ones(n) * 0.5
y0_test_3 = np.array([n**2 for n in range(n)])
y0s = [y0_test_1,y0_test_2,y0_test_3]

# %%
# Plotting
K = 1000
error_list = []
solution_list = []
colors = ['green', 'yellow', 'blue']
for index, y0 in enumerate(y0s):
    data = NewtonSolve(y0, K)
    errors = data[2]
    error_norm = [np.linalg.norm(error) for error in errors]
    error_list.append(error_norm)
    solution_list.append(data[1][-1])
    plt.plot(range(K), error_list[index], label = f'{y0}', color=colors[index])
    plt.xlabel('Iterations (K)')
    plt.ylabel(r'Error $||\vec y - (M  \vec y + e^{\vec y} ))||$')
    plt.yscale('log')
    plt.title('Convergence behavior across errors')
    plt.show()
    print('y0 sequence (starting guess):', y0s[index])
    print('first error of sequence:',error_list[0] )
    print('last error of sequence:',error_list[-1] )
    print('(best guess of) solution:', solution_list[index] )
# Out:
# y0 sequence (starting guess): [1. 1. 1. 1. 1.]
# first error of sequence: [2.236067977499779, 0.23375817674131139, 0.2511836152517237, 0.2511846716867728, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.2511846 ...
# last error of sequence: [2.236067977499779, 0.23375817674131139, 0.2511836152517237, 0.2511846716867728, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467 ...
# (best guess of) solution: [0.07748131 0.124947   0.14093802 0.124947   0.07748131]
# y0 sequence (starting guess): [0.5 0.5 0.5 0.5 0.5]
# first error of sequence: [2.236067977499779, 0.23375817674131139, 0.2511836152517237, 0.2511846716867728, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.2511846 ...
# last error of sequence: [0.0951267661244072, 0.2509328009476671, 0.25118467146664064, 0.25118467168677644, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.2511846716867767, 0.25118467168 ...
# (best guess of) solution: [0.07748131 0.124947   0.14093802 0.124947   0.07748131]
# C:\Users\nitai\AppData\Local\Temp\ipykernel_11320\2526966696.py:23: RuntimeWarning: overflow encountered in exp
#   error = y - (M @ y + np.exp(y))
# C:\Users\nitai\AppData\Local\Temp\ipykernel_11320\3911868292.py:19: RuntimeWarning: overflow encountered in exp
#   main_diagonal = -2*np.ones(n) / h**2 + np.exp(y)
# C:\Users\nitai\AppData\Local\Temp\ipykernel_11320\3911868292.py:5: RuntimeWarning: overflow encountered in exp
#   E = np.exp(y)
# y0 sequence (starting guess): [ 0  1  4  9 16]
# first error of sequence: [2.236067977499779, 0.23375817674131139, 0.2511836152517237, 0.2511846716867728, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.25118467168677666, 0.25118467168677655, 0.2511846 ...
# last error of sequence: [3268504.66499018, 1202220.3484643218, 442083.5922758044, 162440.84534621343, 59489.99235375489, 22156.882871403486, 8078.548559921736, 2883.738181812617, 987.0621308754785, 419.0471487619028, 240.25558517328324, 305.08582888524353, 927.3957267361982, 609.2814266586261, 365.1090787361654, 175.59429339547856, 268.16537438207837, 1.322174846427011e+68, 4.864009436345063e+67, 1.789369073295244e+67, 6.58272094733316e+66, 2.4216477034924704e+66, 8.908744038749166e+65, 3.277343778514461e+65, 1.2056673977666033e+65, 4.435402485290051e+64, 1.6316933876589303e+64, 6.002664516151049e+63, 2.208256867741294e+63, 8.123723024676669e+62, 2.988550686549632e+62, 1.099426356480409e+62, 4.044563536311678e+61, 1.4879117735207326e+61, 5.473721517552167e+60, 2.0136696130051904e+60, 7.40787651936264e+59, 2.7252054742101772e+59, 1.0025470669297955e+59, 3.6881645473020177e+58, 1.3567999126097918e+58, 4.99138793632352e+57, 1.8362290046845752e+57, 6.755109001061553e+56, 2.485065724362704e+56, 9.14204589952857e+55, 3.363170736682246e+55, 1.2372413711748128e+55, 4.551556642219792e+54, 1.6744241139999834e+54, 6.159862073423013e+53, 2.26608661726402e+53, 8.336466784051718e+52, 3.066814741861237e+52, 1.128218093412253e+52, 4.1504824172400976e+51, 1.5268771522461842e+51, 5.617067135057695e+50, 2.0664035186674994e+50, 7.601873716821017e+49, 2.796573054799991e+49, 1.028801732594934e+49, 3.7847500646323595e+48, 1.3923317387505327e+48, 5.122102219768086e+47, 1.8843161022312875e+47, 6.932011546791965e+46, 2.5501445340278136e+46, 9.381457460845603e+45, 3.4512453280695385e+45, 1.2696422026357729e+45, 4.670752639933272e+44, 1.7182738710286912e+44, 6.321176314535259e+43, 2.3254308101373883e+43, 8.554781869161969e+42, 3.147128373370892e+42, 1.157763827290474e+42, 4.259175097921298e+41, 1.5668629548746104e+41, 5.764166682315065e+40, 2.1205184179091127e+40, 7.800951305741554e+39, 2.869809606961836e+39, 1.0557439544775569e+39, 3.883864959933323e+38, 1.4287940710456169e+38, 5.2562396440533155e+37, 1.9336625029175147e+37, 7.113546809874679e+36, 2.616927625163593e+36, 9.627138723312922e+35, 3.5416264136123106e+35, 1.3028915458777162e+35, 4.793070138044908e+34, 1.7632719638794889e+34, 6.486715047052579e+33, 2.3863291065480893e+33, 8.778814181680583e+32, 3.2295452553045856e+32, 1.188083303759334e+32, 4.370714218521048e+31, 1.6078959042296002e+31, 5.915118467098363e+30, 2.176050476139024e+30, 8.005242331228751e+29, 2.9449640752544075e+29, 1.0833917382745648e+29, 3.985575472462044e+28, 1.466211277555944e+28, 5.393889854265472e+27, 1.984301185327494e+27, 7.299836111741092e+26, 2.685459629430427e+26, 9.879253877633342e+25, 3.6343743956945584e+25, 1.3370116216959125e+25, 4.918590882292162e+24, 1.8094484651285918e+24, 6.656588901800304e+23, 2.4488222053023207e+23, 9.008713444148368e+22, 3.3141204675069607e+22, 1.2191967855612998e+22, 4.4851743215030984e+21, 1.6500034229510626e+21, 6.07002337166204e+20, 2.2330368058646253e+20, 8.214883322567408e+19, 3.022086685994699e+19, 1.111763561215386e+19, 4.089949576146887e+18, 1.5046083644922934e+18, 5.535144843113016e+17, 2.036265991687397e+17, 7.491003950983677e+16, 2.755786347300899e+16, 1.0137971414329014e+16, 3729551258514986.0, 1372025232802307.5, 504739875915994.56, 185683423488484.8, 68309114067310.266, 25129518709563.65, 9244633299342.469, 3400910531537.9883, 1251125064698.2373, 460263189812.68933, 169321364578.71634, 62289848966.95413, 22915154585.02149, 8430014018.621097, 3101228602.082856, 1140878000.5253778, 419705313.8201777, 154400694.17816162, 56799919.70658288, 20895786.116982017, 7686868.1618969, 2827918.824836079, 61608357119652.7, 22664447988293.566, 8337784460010.99, 3067299487339.4917, 8789172948647170.0, 3233356032707122.0, 1189485210420238.8, 437587154490719.0, 160979317857425.34, 59220987904662.984, 21786183935810.812, 8014693843721.587, 2948441092212.278, 7.693537301425672e+134, 2.830294203080123e+134, 1.0412070497798883e+134, 3.830386676167914e+133, 1.4091205098991908e+133, 5.1838646572493216e ...
# (best guess of) solution: [nan nan nan nan nan]
